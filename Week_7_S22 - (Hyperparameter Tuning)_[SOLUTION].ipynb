# %% [markdown]
# # Preamble
# This problem set is an extension of Problem Set 6.  You will need the following artifacts from last week:
#
# * The MNIST 784 dataset from OpenML, with dimensionality reduced to about 75\%.
# * The Support Vector Machine classifier.
# * Recoded target variables, such that the target variable is 1 if the digit is less than 5, and 0 otherwise.
#
# (You may copy these artifacts from the posted solutions if needed.)  As with last week, please use the first 60,000 observations as training data, and the remaining 10,000 images as test data.

# %%
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.model_selection import (cross_val_predict, RandomizedSearchCV)
from sklearn.metrics import f1_score
import numpy as np

# %%
#fetch OpenML data
X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)

#split into test/training sets
N=60000
X_train, y_train = X[:N, :], y[:N]
X_test, y_test = X[N:, :], y[N:]

#scale data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# PCA
pca = PCA(n_components = 0.75)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

#SVM classifier from last week
#May vary based on best classifer from last week
svm = SVC(coef0=0.3864834922270453, degree=4, kernel='poly')

# recoded target variable
recode_fn = lambda y: np.choose(np.isin(y, list("01234")), [-1,1])
y_test_rcd, y_train_rcd = (recode_fn(y) for y in [y_test, y_train])

# %% [markdown]
# We can create a smaller subset for hyperparameter optimization

# %%
N_hpo = int(1e4)
hpo_subset = lambda K : np.take(K, np.arange(0, N_hpo), 0)
y_hpo, X_hpo = map(hpo_subset, [y_train_rcd, X_train_pca])

# %% [markdown]
# # Problem 1 -- Classifiers
#
# Construct 3 classifiers using different algorithms, not including the SVM model built last week, that classify the MNIST dataset with an $F_1$ score of at least 0.9.  At least one classifier must use gradient boosting (AdaBoost, Gradient Boost, or xgboost).  Show the $F_1$ score and classification report for each model.

# %%
classifiers = {'svm': svm}

# %%
from sklearn.utils.fixes import loguniform
from scipy.stats import randint, uniform
def test_classifier(clf, params, n_iter=20):
  grid = RandomizedSearchCV(clf, params, 
                            scoring='f1', cv=3, 
                            verbose=3, n_iter=n_iter)
  grid.fit(X_hpo, y_hpo)
  grid.best_estimator_.fit(X_train_pca, y_train_rcd)
  return grid.best_estimator_, grid.best_score_

# %% [markdown]
# ### Gradient boosted tree

# %%
from xgboost import XGBClassifier
params = {
          'learning_rate': loguniform(1e-2, 0.2),
          'n_estimators': randint(50,500),
          'max_depth': randint(2, 10)
}
xgclf = XGBClassifier()
classifiers['xgboost'] = test_classifier(xgclf, params)
classifiers['xgboost']
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV 1/3] END learning_rate=0.08116387404614266, max_depth=4, n_estimators=436;, score=0.942 total time=  25.0s
# [CV 2/3] END learning_rate=0.08116387404614266, max_depth=4, n_estimators=436;, score=0.954 total time=  24.2s
# [CV 3/3] END learning_rate=0.08116387404614266, max_depth=4, n_estimators=436;, score=0.928 total time=  24.6s
# [CV 1/3] END learning_rate=0.17901563859157918, max_depth=4, n_estimators=455;, score=0.944 total time=  24.7s
# [CV 2/3] END learning_rate=0.17901563859157918, max_depth=4, n_estimators=455;, score=0.950 total time=  25.0s
# [CV 3/3] END learning_rate=0.17901563859157918, max_depth=4, n_estimators=455;, score=0.935 total time=  24.4s
# [CV 1/3] END learning_rate=0.013249149636252563, max_depth=2, n_estimators=90;, score=0.800 total time=   2.5s
# [CV 2/3] END learning_rate=0.013249149636252563, max_depth=2, n_estimators=90;, score=0.815 total time=   2.6s
# [CV 3/3] END learning_rate=0.013249149636252563, max_depth=2, n_estimators=90;, score=0.789 total time=   2.5s
# [CV 1/3] END learning_rate=0.18851212006172038, max_depth=8, n_estimators=411;, score=0.946 total time=  30.9s
# [CV 2/3] END learning_rate=0.18851212006172038, max_depth=8, n_estimators=411;, score=0.955 total time=  31.5s
# [CV 3/3] END learning_rate=0.18851212006172038, max_depth=8, n_estimators=411;, score=0.938 total time=  31.6s
# [CV 1/3] END learning_rate=0.13162357587778856, max_depth=8, n_estimators=224;, score=0.945 total time=  23.9s
# [CV 2/3] END learning_rate=0.13162357587778856, max_depth=8, n_estimators=224;, score=0.953 total time=  24.1s
# [CV 3/3] END learning_rate=0.13162357587778856, max_depth=8, n_estimators=224;, score=0.938 total time=  23.5s
# [CV 1/3] END learning_rate=0.08645465478019153, max_depth=2, n_estimators=50;, score=0.837 total time=   1.4s
# [CV 2/3] END learning_rate=0.08645465478019153, max_depth=2, n_estimators=50;, score=0.861 total time=   1.5s
# [CV 3/3] END learning_rate=0.08645465478019153, max_depth=2, n_estimators=50;, score=0.840 total time=   1.5s
# [CV 1/3] END learning_rate=0.010272899304162305, max_depth=5, n_estimators=157;, score=0.882 total time=  12.2s
# [CV 2/3] END learning_rate=0.010272899304162305, max_depth=5, n_estimators=157;, score=0.894 total time=  12.4s
# [CV 3/3] END learning_rate=0.010272899304162305, max_depth=5, n_estimators=157;, score=0.875 total time=  12.1s
# [CV 1/3] END learning_rate=0.08310597562039933, max_depth=3, n_estimators=352;, score=0.923 total time=  14.4s
# [CV 2/3] END learning_rate=0.08310597562039933, max_depth=3, n_estimators=352;, score=0.941 total time=  14.3s
# [CV 3/3] END learning_rate=0.08310597562039933, max_depth=3, n_estimators=352;, score=0.913 total time=  14.3s
# [CV 1/3] END learning_rate=0.09479700418283236, max_depth=6, n_estimators=150;, score=0.941 total time=  13.6s
# [CV 2/3] END learning_rate=0.09479700418283236, max_depth=6, n_estimators=150;, score=0.950 total time=  13.7s
# [CV 3/3] END learning_rate=0.09479700418283236, max_depth=6, n_estimators=150;, score=0.930 total time=  13.7s
# [CV 1/3] END learning_rate=0.15607614286365448, max_depth=2, n_estimators=233;, score=0.907 total time=   6.3s
# [CV 2/3] END learning_rate=0.15607614286365448, max_depth=2, n_estimators=233;, score=0.925 total time=   6.4s
# [CV 3/3] END learning_rate=0.15607614286365448, max_depth=2, n_estimators=233;, score=0.901 total time=   6.4s
# [CV 1/3] END learning_rate=0.16651529023242564, max_depth=9, n_estimators=236;, score=0.951 total time=  24.4s
# [CV 2/3] END learning_rate=0.16651529023242564, max_depth=9, n_estimators=236;, score=0.953 total time=  24.5s
# [CV 3/3] END learning_rate=0.16651529023242564, max_depth=9, n_estimators=236;, score=0.937 total time=  24.0s
# [CV 1/3] END learning_rate=0.0572870219266904, max_depth=8, n_estimators=468;, score=0.948 total time=  51.9s
# [CV 2/3] END learning_rate=0.0572870219266904, max_depth=8, n_estimators=468;, score=0.955 total time=  51.7s
# [CV 3/3] END learning_rate=0.0572870219266904, max_depth=8, n_estimators=468;, score=0.937 total time=  50.0s
# [CV 1/3] END learning_rate=0.029114968819855275, max_depth=7, n_estimators=262;, score=0.935 total time=  28.3s
# [CV 2/3] END learning_rate=0.029114968819855275, max_depth=7, n_estimators=262;, score=0.949 total time=  28.7s
# [CV 3/3] END learning_rate=0.029114968819855275, max_depth=7, n_estimators=262;, score=0.929 total time=  28.3s
# [CV 1/3] END learning_rate=0.010277234477140995, max_depth=5, n_estimators=263;, score=0.897 total time=  19.7s
# [CV 2/3] END learning_rate=0.010277234477140995, max_depth=5, n_estimators=263;, score=0.915 total time=  20.2s
# [CV 3/3] END learning_rate=0.010277234477140995, max_depth=5, n_estimators=263;, score=0.889 total time=  20.2s
# [CV 1/3] END learning_rate=0.017613140566333594, max_depth=7, n_estimators=316;, score=0.930 total time=  34.4s
# [CV 2/3] END learning_rate=0.017613140566333594, max_depth=7, n_estimators=316;, score=0.947 total time=  35.1s
# [CV 3/3] END learning_rate=0.017613140566333594, max_depth=7, n_estimators=316;, score=0.925 total time=  34.8s
# [CV 1/3] END learning_rate=0.01891926969406568, max_depth=8, n_estimators=210;, score=0.929 total time=  26.3s
# [CV 2/3] END learning_rate=0.01891926969406568, max_depth=8, n_estimators=210;, score=0.942 total time=  27.0s
# [CV 3/3] END learning_rate=0.01891926969406568, max_depth=8, n_estimators=210;, score=0.919 total time=  27.2s
# [CV 1/3] END learning_rate=0.01450944779377617, max_depth=2, n_estimators=310;, score=0.839 total time=   8.4s
# [CV 2/3] END learning_rate=0.01450944779377617, max_depth=2, n_estimators=310;, score=0.864 total time=   8.6s
# [CV 3/3] END learning_rate=0.01450944779377617, max_depth=2, n_estimators=310;, score=0.844 total time=   8.5s
# [CV 1/3] END learning_rate=0.0955914143848209, max_depth=6, n_estimators=50;, score=0.920 total time=   4.8s
# [CV 2/3] END learning_rate=0.0955914143848209, max_depth=6, n_estimators=50;, score=0.935 total time=   4.8s
# [CV 3/3] END learning_rate=0.0955914143848209, max_depth=6, n_estimators=50;, score=0.916 total time=   4.8s
# [CV 1/3] END learning_rate=0.19299343762455148, max_depth=9, n_estimators=409;, score=0.952 total time=  30.8s
# [CV 2/3] END learning_rate=0.19299343762455148, max_depth=9, n_estimators=409;, score=0.954 total time=  31.1s
# [CV 3/3] END learning_rate=0.19299343762455148, max_depth=9, n_estimators=409;, score=0.939 total time=  30.2s
# [CV 1/3] END learning_rate=0.025729470710812823, max_depth=9, n_estimators=287;, score=0.941 total time=  40.1s
# [CV 2/3] END learning_rate=0.025729470710812823, max_depth=9, n_estimators=287;, score=0.949 total time=  40.8s
# [CV 3/3] END learning_rate=0.025729470710812823, max_depth=9, n_estimators=287;, score=0.932 total time=  40.6s
# (XGBClassifier(learning_rate=0.19299343762455148, max_depth=9, n_estimators=409),
#  0.9485250880423896)

# %% [markdown]
# ## Random forest model

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
params = {'max_features': uniform(),
          'max_depth': randint(1, 20),
          'min_samples_leaf': randint(1, 20)}
classifiers['rfc'] = test_classifier(rfc, params)
classifiers['rfc']
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV 1/3] END max_depth=2, max_features=0.65016555342138, min_samples_leaf=6;, score=0.748 total time=   9.2s
# [CV 2/3] END max_depth=2, max_features=0.65016555342138, min_samples_leaf=6;, score=0.772 total time=   9.1s
# [CV 3/3] END max_depth=2, max_features=0.65016555342138, min_samples_leaf=6;, score=0.758 total time=   9.2s
# [CV 1/3] END max_depth=3, max_features=0.9452290487135915, min_samples_leaf=17;, score=0.782 total time=  18.9s
# [CV 2/3] END max_depth=3, max_features=0.9452290487135915, min_samples_leaf=17;, score=0.810 total time=  18.6s
# [CV 3/3] END max_depth=3, max_features=0.9452290487135915, min_samples_leaf=17;, score=0.778 total time=  20.0s
# [CV 1/3] END max_depth=5, max_features=0.6793287538531652, min_samples_leaf=17;, score=0.858 total time=  21.1s
# [CV 2/3] END max_depth=5, max_features=0.6793287538531652, min_samples_leaf=17;, score=0.864 total time=  21.3s
# [CV 3/3] END max_depth=5, max_features=0.6793287538531652, min_samples_leaf=17;, score=0.850 total time=  21.2s
# [CV 1/3] END max_depth=13, max_features=0.10974358677108764, min_samples_leaf=9;, score=0.920 total time=   6.3s
# [CV 2/3] END max_depth=13, max_features=0.10974358677108764, min_samples_leaf=9;, score=0.928 total time=   6.3s
# [CV 3/3] END max_depth=13, max_features=0.10974358677108764, min_samples_leaf=9;, score=0.911 total time=   6.3s
# [CV 1/3] END max_depth=9, max_features=0.41251202015577737, min_samples_leaf=18;, score=0.900 total time=  19.0s
# [CV 2/3] END max_depth=9, max_features=0.41251202015577737, min_samples_leaf=18;, score=0.914 total time=  19.1s
# [CV 3/3] END max_depth=9, max_features=0.41251202015577737, min_samples_leaf=18;, score=0.898 total time=  19.2s
# [CV 1/3] END max_depth=18, max_features=0.26213576122784343, min_samples_leaf=6;, score=0.924 total time=  15.9s
# [CV 2/3] END max_depth=18, max_features=0.26213576122784343, min_samples_leaf=6;, score=0.937 total time=  16.1s
# [CV 3/3] END max_depth=18, max_features=0.26213576122784343, min_samples_leaf=6;, score=0.915 total time=  16.4s
# [CV 1/3] END max_depth=10, max_features=0.7674003426153125, min_samples_leaf=17;, score=0.900 total time=  37.8s
# [CV 2/3] END max_depth=10, max_features=0.7674003426153125, min_samples_leaf=17;, score=0.914 total time=  37.5s
# [CV 3/3] END max_depth=10, max_features=0.7674003426153125, min_samples_leaf=17;, score=0.898 total time=  38.5s
# [CV 1/3] END max_depth=7, max_features=0.18528752336668897, min_samples_leaf=1;, score=0.896 total time=   8.4s
# [CV 2/3] END max_depth=7, max_features=0.18528752336668897, min_samples_leaf=1;, score=0.908 total time=   8.3s
# [CV 3/3] END max_depth=7, max_features=0.18528752336668897, min_samples_leaf=1;, score=0.892 total time=   8.3s
# [CV 1/3] END max_depth=12, max_features=0.862217843788607, min_samples_leaf=3;, score=0.917 total time=  51.5s
# [CV 2/3] END max_depth=12, max_features=0.862217843788607, min_samples_leaf=3;, score=0.926 total time=  51.1s
# [CV 3/3] END max_depth=12, max_features=0.862217843788607, min_samples_leaf=3;, score=0.912 total time=  52.3s
# [CV 1/3] END max_depth=11, max_features=0.2374874246490084, min_samples_leaf=9;, score=0.911 total time=  13.1s
# [CV 2/3] END max_depth=11, max_features=0.2374874246490084, min_samples_leaf=9;, score=0.931 total time=  12.9s
# [CV 3/3] END max_depth=11, max_features=0.2374874246490084, min_samples_leaf=9;, score=0.908 total time=  12.8s
# [CV 1/3] END max_depth=1, max_features=0.22136965001511666, min_samples_leaf=13;, score=0.748 total time=   1.9s
# [CV 2/3] END max_depth=1, max_features=0.22136965001511666, min_samples_leaf=13;, score=0.752 total time=   1.8s
# [CV 3/3] END max_depth=1, max_features=0.22136965001511666, min_samples_leaf=13;, score=0.739 total time=   1.8s
# [CV 1/3] END max_depth=3, max_features=0.6395877484387933, min_samples_leaf=7;, score=0.803 total time=  12.8s
# [CV 2/3] END max_depth=3, max_features=0.6395877484387933, min_samples_leaf=7;, score=0.818 total time=  13.0s
# [CV 3/3] END max_depth=3, max_features=0.6395877484387933, min_samples_leaf=7;, score=0.808 total time=  12.8s
# [CV 1/3] END max_depth=12, max_features=0.009660396546877892, min_samples_leaf=12;, score=0.875 total time=   0.8s
# [CV 2/3] END max_depth=12, max_features=0.009660396546877892, min_samples_leaf=12;, score=0.904 total time=   0.8s
# [CV 3/3] END max_depth=12, max_features=0.009660396546877892, min_samples_leaf=12;, score=0.875 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=0.4832083500901835, min_samples_leaf=14;, score=0.866 total time=  14.9s
# [CV 2/3] END max_depth=5, max_features=0.4832083500901835, min_samples_leaf=14;, score=0.870 total time=  14.9s
# [CV 3/3] END max_depth=5, max_features=0.4832083500901835, min_samples_leaf=14;, score=0.861 total time=  15.0s
# [CV 1/3] END max_depth=1, max_features=0.8148812773066741, min_samples_leaf=5;, score=0.531 total time=   6.0s
# [CV 2/3] END max_depth=1, max_features=0.8148812773066741, min_samples_leaf=5;, score=0.690 total time=   6.0s
# [CV 3/3] END max_depth=1, max_features=0.8148812773066741, min_samples_leaf=5;, score=0.607 total time=   6.0s
# [CV 1/3] END max_depth=14, max_features=0.8166311416562783, min_samples_leaf=2;, score=0.919 total time=  51.6s
# [CV 2/3] END max_depth=14, max_features=0.8166311416562783, min_samples_leaf=2;, score=0.931 total time=  51.4s
# [CV 3/3] END max_depth=14, max_features=0.8166311416562783, min_samples_leaf=2;, score=0.913 total time=  51.7s
# [CV 1/3] END max_depth=18, max_features=0.09854739369409493, min_samples_leaf=18;, score=0.911 total time=   5.1s
# [CV 2/3] END max_depth=18, max_features=0.09854739369409493, min_samples_leaf=18;, score=0.921 total time=   5.0s
# [CV 3/3] END max_depth=18, max_features=0.09854739369409493, min_samples_leaf=18;, score=0.908 total time=   5.1s
# [CV 1/3] END max_depth=14, max_features=0.005959983792154122, min_samples_leaf=16;, score=0.876 total time=   0.8s
# [CV 2/3] END max_depth=14, max_features=0.005959983792154122, min_samples_leaf=16;, score=0.892 total time=   0.8s
# [CV 3/3] END max_depth=14, max_features=0.005959983792154122, min_samples_leaf=16;, score=0.874 total time=   0.8s
# [CV 1/3] END max_depth=16, max_features=0.955519020260971, min_samples_leaf=1;, score=0.920 total time= 1.1min
# [CV 2/3] END max_depth=16, max_features=0.955519020260971, min_samples_leaf=1;, score=0.927 total time= 1.1min
# [CV 3/3] END max_depth=16, max_features=0.955519020260971, min_samples_leaf=1;, score=0.912 total time= 1.1min
# [CV 1/3] END max_depth=19, max_features=0.6329174129936953, min_samples_leaf=6;, score=0.920 total time=  39.1s
# [CV 2/3] END max_depth=19, max_features=0.6329174129936953, min_samples_leaf=6;, score=0.930 total time=  38.7s
# [CV 3/3] END max_depth=19, max_features=0.6329174129936953, min_samples_leaf=6;, score=0.915 total time=  38.5s
# (RandomForestClassifier(max_depth=18, max_features=0.26213576122784343,
#                         min_samples_leaf=6), 0.9252254322144949)

# %% [markdown]
# ## Logistic regression model
# A logistic regression model by itself produces accuracy at best in the high 80s.  As we saw in Week 4, we can add dimensionality by adding polynomial features.  Last week, we may have observed the polynomial kernel performed well, which suggests that that adding polynomial features can improve predictive accuracy.
#
# Note: ideally, we would test multiple degrees; however, we exhaust available memory in Colab using polynomial degree greater than 2.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

lrclf = make_pipeline(PolynomialFeatures(2), 
                        LogisticRegression(max_iter=2000))

params = {'logisticregression__C': loguniform(1e-4,1e4)}
classifiers['logreg'] = test_classifier(lrclf, params)
classifiers['logreg']
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV 1/3] END logisticregression__C=52.13339337121985;, score=0.949 total time=  22.9s
# [CV 2/3] END logisticregression__C=52.13339337121985;, score=0.956 total time=  31.1s
# [CV 3/3] END logisticregression__C=52.13339337121985;, score=0.940 total time=  27.8s
# [CV 1/3] END logisticregression__C=0.00013211684329604987;, score=0.961 total time=   4.8s
# [CV 2/3] END logisticregression__C=0.00013211684329604987;, score=0.967 total time=   7.2s
# [CV 3/3] END logisticregression__C=0.00013211684329604987;, score=0.948 total time=   9.3s
# [CV 1/3] END logisticregression__C=11.940107503366715;, score=0.949 total time=  21.9s
# [CV 2/3] END logisticregression__C=11.940107503366715;, score=0.957 total time=  27.7s
# [CV 3/3] END logisticregression__C=11.940107503366715;, score=0.941 total time=  32.8s
# [CV 1/3] END logisticregression__C=0.0005352251994702991;, score=0.960 total time=   6.2s
# [CV 2/3] END logisticregression__C=0.0005352251994702991;, score=0.965 total time=  10.6s
# [CV 3/3] END logisticregression__C=0.0005352251994702991;, score=0.949 total time=  10.5s
# [CV 1/3] END logisticregression__C=1283.0307324444343;, score=0.949 total time=  10.1s
# [CV 2/3] END logisticregression__C=1283.0307324444343;, score=0.954 total time=  12.8s
# [CV 3/3] END logisticregression__C=1283.0307324444343;, score=0.939 total time=  11.4s
# [CV 1/3] END logisticregression__C=1.0372280971485295;, score=0.950 total time=  18.5s
# [CV 2/3] END logisticregression__C=1.0372280971485295;, score=0.958 total time=  32.8s
# [CV 3/3] END logisticregression__C=1.0372280971485295;, score=0.942 total time=  31.5s
# [CV 1/3] END logisticregression__C=1692.8735811055612;, score=0.949 total time=   9.4s
# [CV 2/3] END logisticregression__C=1692.8735811055612;, score=0.954 total time=  11.6s
# [CV 3/3] END logisticregression__C=1692.8735811055612;, score=0.939 total time=  16.4s
# [CV 1/3] END logisticregression__C=0.0015170938077639817;, score=0.958 total time=  10.1s
# [CV 2/3] END logisticregression__C=0.0015170938077639817;, score=0.963 total time=  13.2s
# [CV 3/3] END logisticregression__C=0.0015170938077639817;, score=0.949 total time=  11.9s
# [CV 1/3] END logisticregression__C=2.21912165271899;, score=0.949 total time=  26.4s
# [CV 2/3] END logisticregression__C=2.21912165271899;, score=0.957 total time=  24.7s
# [CV 3/3] END logisticregression__C=2.21912165271899;, score=0.942 total time=  22.5s
# [CV 1/3] END logisticregression__C=26.023600905525274;, score=0.949 total time=  21.0s
# [CV 2/3] END logisticregression__C=26.023600905525274;, score=0.956 total time=  35.2s
# [CV 3/3] END logisticregression__C=26.023600905525274;, score=0.941 total time=  35.1s
# [CV 1/3] END logisticregression__C=0.0012699696870982521;, score=0.959 total time=   8.8s
# [CV 2/3] END logisticregression__C=0.0012699696870982521;, score=0.962 total time=  13.5s
# [CV 3/3] END logisticregression__C=0.0012699696870982521;, score=0.948 total time=  11.1s
# [CV 1/3] END logisticregression__C=8272.815425922243;, score=0.952 total time=   8.6s
# [CV 2/3] END logisticregression__C=8272.815425922243;, score=0.955 total time=  14.8s
# [CV 3/3] END logisticregression__C=8272.815425922243;, score=0.940 total time=  11.1s
# [CV 1/3] END logisticregression__C=0.27192901382743895;, score=0.950 total time=  15.9s
# [CV 2/3] END logisticregression__C=0.27192901382743895;, score=0.959 total time=  31.1s
# [CV 3/3] END logisticregression__C=0.27192901382743895;, score=0.943 total time=  18.0s
# [CV 1/3] END logisticregression__C=111.85315861073687;, score=0.948 total time=  20.3s
# [CV 2/3] END logisticregression__C=111.85315861073687;, score=0.955 total time=  26.4s
# [CV 3/3] END logisticregression__C=111.85315861073687;, score=0.940 total time=  25.4s
# [CV 1/3] END logisticregression__C=480.32771973566304;, score=0.947 total time=  19.6s
# [CV 2/3] END logisticregression__C=480.32771973566304;, score=0.955 total time=  29.8s
# [CV 3/3] END logisticregression__C=480.32771973566304;, score=0.940 total time=  22.1s
# [CV 1/3] END logisticregression__C=0.004368495783199262;, score=0.956 total time=  12.1s
# [CV 2/3] END logisticregression__C=0.004368495783199262;, score=0.961 total time=  15.2s
# [CV 3/3] END logisticregression__C=0.004368495783199262;, score=0.947 total time=  16.1s
# [CV 1/3] END logisticregression__C=0.01400740636987058;, score=0.955 total time=   9.9s
# [CV 2/3] END logisticregression__C=0.01400740636987058;, score=0.961 total time=  17.7s
# [CV 3/3] END logisticregression__C=0.01400740636987058;, score=0.946 total time=  18.8s
# [CV 1/3] END logisticregression__C=4.847010644859155;, score=0.950 total time=  19.8s
# [CV 2/3] END logisticregression__C=4.847010644859155;, score=0.957 total time=  32.5s
# [CV 3/3] END logisticregression__C=4.847010644859155;, score=0.942 total time=  22.7s
# [CV 1/3] END logisticregression__C=0.09001598822100046;, score=0.953 total time=  14.0s
# [CV 2/3] END logisticregression__C=0.09001598822100046;, score=0.960 total time=  18.8s
# [CV 3/3] END logisticregression__C=0.09001598822100046;, score=0.943 total time=  23.6s
# [CV 1/3] END logisticregression__C=0.004515116463487261;, score=0.956 total time=  11.6s
# [CV 2/3] END logisticregression__C=0.004515116463487261;, score=0.961 total time=  14.3s
# [CV 3/3] END logisticregression__C=0.004515116463487261;, score=0.947 total time=  11.7s
# (Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                  ('logisticregression',
#                   LogisticRegression(C=0.00013211684329604987, max_iter=2000))]),
#  0.9586893948324802)

# %% [markdown]
# # Problem 2 -- Voting ensemble model
#
# Build a voting ensemble model that combines the three classifiers from the previous problem, in addition to the SVM model developed last week.  What is the $F_1$ score of the ensemble model?

# %%
from sklearn.ensemble import VotingClassifier

# %% [markdown]
# ## Problem 3 -- Stacking ensemble model
# Stacking uses a final classifier (often a logistic regression) that outputs an aggregate of the predictors. Repeat the previous problem using a `StackingClassifier` rather than voting to compute the final prediction.  What is the $F_1$ score of the stacking classifier?

# %% [markdown]
# ## Problem 4 -- Evaluation
#
# At this point in the assignment, you have six classifiers:
#
# * the support vector classifier from last week,
# * the three classifiers from problem 1,
# * the voting classifier from problem 2, and
# * the stacking classifier from problem 3
#
# Identify the model with the highest $F_1$ score, and train this model with the full training dataset.  Finally, score the test data against this model.  Does the model demonstrate predictive validity (i.e., are the $F_1$ scores for the test data comparable to the training data)?
